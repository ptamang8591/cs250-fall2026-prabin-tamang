# %% [markdown]
# <a href="https://colab.research.google.com/github/ptamang8591/cs250-fall2026-prabin-tamang/blob/main/labs/L02_Prabin_Tamang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 250 — Lab 2
# ## Variables, Data Types & Input/Output
#
# **San Francisco Bay University · Fall 2026 ·**
# **Week 2, Session 1 · 50 minutes**
#
# ---
#
# ### What you will practise
# 1. Creating variables and choosing good names
# 2. Identifying and inspecting data types with `type()`
# 3. Using named constants
# 4. Producing formatted output with `print()` and f-strings
# 5. Reading user input with `input()` and converting it with `int()` / `float()`
# 6. Reading an error message and fixing the bug
#
# ### How to work through this notebook
# - Run every cell **in order** (`Shift + Enter`).
# - Cells marked **GUIDED EXAMPLE** are already written — run them and read the output.
# - Cells marked **TASK** contain `# TODO` lines that you complete.
# - Cells marked **CHECK** verify your work automatically. A message tells you if you passed.
# - If a cell throws an error, read the **last line** of the message first.
#
# ### Submitting
# When you are finished, save a copy of the notebook in your GitHub Lab folder, then submit the GitHub URL for the notebook to the Lab 2 assignment in Canvas.

# %% [markdown]
# ---
# ## Part 0 · Identify yourself
#
# Run the cell below after filling in your name and today's date.

# %%
# TODO: replace the placeholder text with your own details
student_name = "Prabin Tamang"
lab_date = "2004-01-30"

print(f"CS 250 Lab 2 — {student_name} — {lab_date}")
# Out:
# CS 250 Lab 2 — Prabin Tamang — 2004-01-30

# %% [markdown]
# ---
# ## Part 1 · Variables and data types
#
# A **variable** is a name that refers to a value stored in memory. Python figures out the
# type from the value you assign — you never declare it.

# %% [markdown]
# ### GUIDED EXAMPLE 1.1 — four core types
#
# Run this cell and read the output carefully. Notice that `type()` reports the *class* of each value.

# %%
course_code = "CS250"      # str  - text in quotes
units       = 3            # int  - whole number
gpa         = 3.85         # float - has a decimal point
is_enrolled = True         # bool - True or False

print(course_code, type(course_code))
print(units,       type(units))
print(gpa,         type(gpa))
print(is_enrolled, type(is_enrolled))
# Out:
# CS250 <class 'str'>
# 3 <class 'int'>
# 3.85 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# ### GUIDED EXAMPLE 1.2 — quotes change everything
#
# `42` and `"42"` look similar when printed, but they are completely different values.
# Predict the output of each line **before** you run the cell.

# %%
print(42 * 2)      # int arithmetic
print("42" * 2)    # str repetition - not arithmetic!
print(10 / 2)      # true division ALWAYS produces a float
print(10 // 2)     # floor division keeps it an int
# Out:
# 84
# 4242
# 5.0
# 5

# %% [markdown]
# ### TASK 1.3 — build a profile
# Create four variables that describe a **fictional character**, using the exact variable names below. Choose values with the required types, then print each variable together with its type.
#
# | Variable | Required type | Example |
# |---|---|---|
# | `first_name` | `str` | `"Maya"` |
# | `birth_year` | `int` | `2004` |
# | `height_m` | `float` | `1.68` |
# | `likes_python` | `bool` | `True` |

# %%
# TODO: create the four variables
first_name   = "Maya"   # TODO
birth_year   = 2004   # TODO
height_m     = 1.68   # TODO
likes_python = True   # TODO

# TODO: print each variable and its type (four print statements)
print(first_name, type(first_name))
print(birth_year, type(birth_year))
print(height_m, type(height_m))
print(likes_python, type(likes_python))
# Out:
# Maya <class 'str'>
# 2004 <class 'int'>
# 1.68 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# #### CHECK 1.3
# Run this cell to verify the types. Do not edit it.

# %%
problems = []
try:
    if first_name is None or birth_year is None or height_m is None or likes_python is None:
        raise ValueError("one or more variables are still None - fill them in")
    if not isinstance(first_name, str):      problems.append("first_name should be a str")
    if not isinstance(birth_year, int):      problems.append("birth_year should be an int")
    if not isinstance(height_m, float):      problems.append("height_m should be a float")
    if not isinstance(likes_python, bool):   problems.append("likes_python should be a bool (True/False)")
except (NameError, ValueError) as e:
    problems.append(str(e))

print("PASSED - all four types are correct." if not problems else "Fix these:\n- " + "\n- ".join(problems))
# Out:
# PASSED - all four types are correct.

# %% [markdown]
# ---
# ## Part 2 · Named constants and formatted output
#
# A **named constant** holds a value that should never change. Python has no `const` keyword,
# so we write the name in `ALL_CAPS` as a promise to other programmers.

# %% [markdown]
# ### GUIDED EXAMPLE 2.1 — constants beat magic numbers
#
# Compare the two versions. Both compute the same answer; only one explains itself.

# %%
# Version A - magic numbers
total_a = 40.00 + 40.00 * 0.0925
print(total_a)

# Version B - named constant
TAX_RATE = 0.0925
subtotal = 40.00
tax      = subtotal * TAX_RATE
total_b  = subtotal + tax
print(f"Subtotal: ${subtotal:.2f}")
print(f"Tax:      ${tax:.2f}")
print(f"Total:    ${total_b:.2f}")
# Out:
# 43.7
# Subtotal: $40.00
# Tax:      $3.70
# Total:    $43.70

# %% [markdown]
# ### GUIDED EXAMPLE 2.2 — f-string format specifiers
#
# Put an `f` before the quote, then write any expression inside `{ }`.
# A colon introduces a **format specifier**.

# %%
value = 1234.56789

print(f"Plain:        {value}")
print(f"2 decimals:   {value:.2f}")
print(f"0 decimals:   {value:.0f}")
print(f"With commas:  {value:,.2f}")
print(f"Right in 12:  |{value:>12.2f}|")
print(f"Left in 12:   |{value:<12.2f}|")
print(f"As percent:   {0.0925:.1%}")
# Out:
# Plain:        1234.56789
# 2 decimals:   1234.57
# 0 decimals:   1235
# With commas:  1,234.57
# Right in 12:  |     1234.57|
# Left in 12:   |1234.57     |
# As percent:   9.2%

# %% [markdown]
# ### TASK 2.3 — a formatted receipt line
#
# Using the constants and variables already defined below, print **exactly** these three lines:
#
# ```
# Item:      Notebook
# Unit cost: $    3.49
# Line total:$   13.96
# ```
#
# Requirements:
# - Use one f-string per line.
# - Show money with two decimals.
# - Right-align the two dollar amounts in a field of width 8 (`{value:>8.2f}`).
# - Compute `line_total` — do **not** type `13.96` yourself.

# %%
ITEM_NAME = "Notebook"
UNIT_COST = 3.49
QUANTITY = 4

# TODO: compute the line total
line_total = UNIT_COST * QUANTITY

# TODO: three print statements using f-strings
print(f"Item: {ITEM_NAME}")
print(f"Unit Cost: ${UNIT_COST:>8.2f}")
print(f"Line Total: ${line_total:>8.2f}")
# Out:
# Item: Notebook
# Unit Cost: $    3.49
# Line Total: $   13.96

# %% [markdown]
# #### CHECK 2.3

# %%
if line_total is None:
    print("line_total has not been computed yet.")
elif abs(line_total - 13.96) < 0.001:
    print("PASSED - line_total is correct.")
else:
    print(f"line_total is {line_total}, expected 13.96")
# Out:
# PASSED - line_total is correct.

# %% [markdown]
# ---
# ## Part 3 · Reading input from the user
#
# `input()` displays a prompt, waits for the user, and returns whatever was typed
# **as a string — always**, even when it looks like a number.
#
# > In Colab a text box appears under the cell. Type your answer and press **Enter**.

# %% [markdown]
# ### GUIDED EXAMPLE 3.1 — the classic Week 2 bug
#
# Run this cell and type **5** at the first prompt and **3** at the second.
# The answer will *not* be 8. Read the output and work out why.

# %%
a = input("First number: ")
b = input("Second number: ")

print("a is", type(a))
print("b is", type(b))
print("a + b gives:", a + b)   # string concatenation, not addition!

# %% [markdown]
# ### GUIDED EXAMPLE 3.2 — the fix: convert on the way in
#
# Wrapping `input()` in `int()` or `float()` converts the text into a number immediately.
# Run this with the same values, 5 and 3.

# %%
a = int(input("First number: "))
b = int(input("Second number: "))

print("a is", type(a))
print("a + b gives:", a + b)   # real addition

# %% [markdown]
# ### TASK 3.3 — shopping trip calculator
#
# Write a complete program that:
#
# 1. Asks the user for the **name**, **price** and **quantity** of **two** items.
# 2. Computes the line total for each item.
# 3. Computes the overall total.
# 4. Prints a tidy summary with all money shown to two decimals.
#
# Type hints: a price is a `float`, a quantity is an `int`, a name is a `str`.
#
# Example run:
# ```
# Item 1 name: Pens
# Item 1 price: 2.25
# Item 1 quantity: 3
#
# Item 2 name: Folder
# Item 2 price: 4.10
# Item 2 quantity: 2
#
# Pens      3 x $2.25 = $6.75
# Folder    2 x $4.10 = $8.20
# Overall total: $14.95
# ```

# %%
def get_float(prompt):
    while True:
        try:
            return float(input(prompt).replace("$", "").strip())
        except ValueError:
            print("Invalid input. Please enter a valid number.")

def get_int(prompt):
    while True:
        try:
            return int(input(prompt).strip())
        except ValueError:
            print("Invalid input. Please enter a whole number.")

# 1. Ask the user for details of two items
item1_name = input("Item 1 name: ").strip()
item1_price = get_float("Item 1 price: ")
item1_qty = get_int("Item 1 quantity: ")

print()  # Blank line separator

item2_name = input("Item 2 name: ").strip()
item2_price = get_float("Item 2 price: ")
item2_qty = get_int("Item 2 quantity: ")

print()  # Blank line before summary

# 2. Compute line totals
line1_total = item1_price * item1_qty
line2_total = item2_price * item2_qty

# 3. Compute overall total
overall_total = line1_total + line2_total

# 4. Print formatted summary
print(f"{item1_name:<15} {item1_qty:>3} x ${item1_price:>6.2f} = ${line1_total:>7.2f}")
print(f"{item2_name:<15} {item2_qty:>3} x ${item2_price:>6.2f} = ${line2_total:>7.2f}")
print("-" * 40)
print(f"{'Overall total:':<28} ${overall_total:>7.2f}")

# %% [markdown]
# ---
# ## Part 4 · Type conversion in detail

# %% [markdown]
# ### GUIDED EXAMPLE 4.1 — what each conversion does
#
# Note that `int()` **truncates** a float — it chops the decimals off, it does not round.

# %%
print(int("42"))        # text of a whole number -> 42
print(int(9.87))        # TRUNCATES -> 9   (not 10!)
print(round(9.87))      # rounds     -> 10
print(float("3.5"))     # -> 3.5
print(float(7))         # -> 7.0
print(str(42) + "!")    # number -> text, so + concatenates
print(int(True))        # -> 1
print(bool(0), bool(""), bool("hi"))   # falsy, falsy, truthy

# %% [markdown]
# ### GUIDED EXAMPLE 4.2 — conversions that fail
#
# Run this cell. It **will** raise an error — that is the point.
# Read the error type and the last line of the message, then comment the line out and run again.

# %%
# print(int("9.87"))  # ValueError: int() cannot read a decimal string
# The fix:
print(int(float("9.87")))

# %% [markdown]
# ### TASK 4.3 — predict, then verify
#
# For each expression in the table, write down your prediction in the `answer_` variable
# as a **string** exactly as Python would print it (or the word `"error"`).
#
# | # | Expression | Your answer variable |
# |---|---|---|
# | 1 | `int(7.99)` | `answer_1` |
# | 2 | `"3" + "4"` | `answer_2` |
# | 3 | `float("12")` | `answer_3` |
# | 4 | `int("twelve")` | `answer_4` |
# | 5 | `bool("")` | `answer_5` |

# %%
# TODO: fill in your predictions as strings, e.g. answer_1 = "7"
answer_1 = "7"
answer_2 = "34"
answer_3 = "12.0"
answer_4 = "error"
answer_5 = "False"

# %% [markdown]
# #### CHECK 4.3

# %%
expected = {"answer_1": "7", "answer_2": "34", "answer_3": "12.0",
            "answer_4": "error", "answer_5": "False"}
given, missing = {}, []
for k in expected:
    v = globals().get(k)
    if v is None:
        missing.append(k)
    else:
        given[k] = str(v).strip().lower()

if missing:
    print("Not answered yet:", ", ".join(missing))
else:
    wrong = [k for k in expected if given[k] != expected[k].lower()]
    if wrong:
        print("Not quite - look again at:", ", ".join(wrong))
    else:
        print("PASSED - all five predictions are correct.")

# %% [markdown]
# ### TASK 4.4 — verify by running
#
# Now actually run the five expressions and compare with your predictions.
# Wrap the one that fails in a comment so the cell finishes.

# %%
# TODO: print each of the five expressions (comment out the one that errors)
print(int(7.99))
print("3" + "4")
print(float("12"))
# print(int("twelve"))  # Raises ValueError: invalid literal for int()
print(bool(""))

# %% [markdown]
# ---
# ## Part 5 · Debugging
#
# ### TASK 5.1 — fix three bugs
#
# The program below is meant to compute the cost of a number of tickets.
# It contains **three** bugs. Run it, read each error, fix it, and run again until it works.
#
# Expected behaviour: with 3 tickets at \$12.50 each it prints `Total for 3 tickets: $37.50`.

# %%
# BUGGY - fixed
TICKET_PRICE = 12.50

number_of_tickets = int(input("How many tickets? "))

total = TICKET_PRICE * number_of_tickets

print(f"Total for {number_of_tickets} tickets: ${total:.2f}")

# %% [markdown]
# #### Hint (open only if stuck)
#
# <details>
# <summary>Show hints</summary>
#
# 1. A variable name cannot contain spaces — Python reads `number of tickets` as three separate things.
# 2. `input()` returns a `str`. Multiplying a `str` by a `float` is a `TypeError`.
# 3. You cannot join a `str` and a number with `+`. Use an f-string, and format the money with `:.2f`.
#
# </details>
